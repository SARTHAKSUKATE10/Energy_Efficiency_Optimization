# %%
import pandas as pd

# %%
file1_path=r"C:\Users\jrsar\OneDrive\Desktop\FinalYearProject\union_processed_dataset.csv"
file2_path=r"C:\Users\jrsar\OneDrive\Desktop\FinalYearProject\sectorwiseMerged.csv"

# %%
print(file1_path)
# Out:
# C:\Users\jrsar\OneDrive\Desktop\FinalYearProject\union_processed_dataset.csv

# %%
df1=pd.read_csv(file1_path)
df2=pd.read_csv(file2_path)

# %%
df1.head()
# Out:
#          Date  Temp (°C)  Humidity (%)  Season  Solar Energy (kWh)  \
# 0  2018-01-01       19.4          62.6  Winter                18.6
# 1  2018-01-02       19.4          64.0  Winter                18.7
# 2  2018-01-03       19.5          66.6  Winter                18.8
# 3  2018-01-04       20.1          66.6  Winter                18.4
# 4  2018-01-05       20.0          66.7  Winter                17.5
#
#    Precipitation (mm)  Population  Total Usage (kWh)  Urban Usage (kWh)  \
# 0                 0.0   3130000.0             2870.0             2009.0
# 1                 0.0   3130000.0             2875.0             2012.5
# 2                 0.0   3130000.0             2890.0             2023.0
# 3                 0.0   3130000.0             2930.0             2051.0
# 4                 0.0   3130000.0             2875.0             2012.5
#
#    Rural Usage (kWh)  Adjusted Total Usage (kWh)
# 0              861.0                         NaN
# ...

# %%
df2.head()
# Out:
#          Date  Temp (°C)  Humidity (%)  Season  Solar Energy (kWh)  \
# 0  2018-01-01       19.4          62.6  Winter                18.6
# 1  2018-01-02       19.4          64.0  Winter                18.7
# 2  2018-01-03       19.5          66.6  Winter                18.8
# 3  2018-01-04       20.1          66.6  Winter                18.4
# 4  2018-01-05       20.0          66.7  Winter                17.5
#
#    Precipitation (mm)  Population  Total Usage (kWh)  Urban Usage (kWh)  \
# 0                 0.0   3130000.0             2870.0             2009.0
# 1                 0.0   3130000.0             2875.0             2012.5
# 2                 0.0   3130000.0             2890.0             2023.0
# 3                 0.0   3130000.0             2930.0             2051.0
# 4                 0.0   3130000.0             2875.0             2012.5
#
#    Rural Usage (kWh)  Urban Household (kWh)  Urban Industrial (kWh)  \
# ...

# %%
df1.describe()
# Out:
#          Temp (°C)  Humidity (%)  Solar Energy (kWh)  Precipitation (mm)  \
# count  2460.000000   2460.000000         2460.000000         1461.000000
# mean     24.469106     70.509959           17.651626            2.987680
# std       2.747167     15.507237            5.882533            9.087594
# min      15.700000     31.300000            2.100000            0.000000
# 25%      22.800000     58.000000           14.200000            0.000000
# 50%      24.200000     70.550000           18.400000            0.100000
# 75%      26.100000     84.900000           22.000000            1.400000
# max      32.900000     96.900000           29.000000          119.000000
#
#        Population  Total Usage (kWh)  Urban Usage (kWh)  Rural Usage (kWh)  \
# count      1461.0        2460.000000        2460.000000        2460.000000
# mean    3130000.0        3414.548112        2385.595523        1032.803109
# std           0.0         671.251692         487.894999         191.991759
# ...

# %%
df2.describe()
# Out:
#          Temp (°C)  Humidity (%)  Solar Energy (kWh)  Precipitation (mm)  \
# count  1729.000000   1729.000000         1729.000000         1729.000000
# mean     24.526374     69.411278           17.863331            1.192944
# std       2.823820     15.885073            5.994646            6.310657
# min      15.700000     31.300000            2.100000            0.000000
# 25%      22.800000     56.500000           14.400000            0.000000
# 50%      24.200000     68.000000           18.600000            0.000000
# 75%      26.200000     84.400000           22.200000            0.000000
# max      32.900000     96.900000           29.000000          119.000000
#
#        Population  Total Usage (kWh)  Urban Usage (kWh)  Rural Usage (kWh)  \
# count      1729.0        2460.000000        2460.000000        2460.000000
# mean    3130000.0        3420.663655        2389.772534        1034.725953
# std           0.0         673.782361         490.759263         193.523325
# ...

# %%
#Checking missing values
missing_values_df1=df1.isnull().sum()
missing_values_df2=df2.isnull().sum()

# %%
#Selecting only numerical values
correlation_df1 = df1.select_dtypes(include=['number']).corr()
correlation_df2 = df2.select_dtypes(include=['number']).corr()

# %%
print(correlation_df1)
# Out:
#                             Temp (°C)  Humidity (%)  Solar Energy (kWh)  \
# Temp (°C)                    1.000000     -0.232650            0.385149
# Humidity (%)                -0.232650      1.000000           -0.842324
# Solar Energy (kWh)           0.385149     -0.842324            1.000000
# Precipitation (mm)          -0.024681      0.353851           -0.364349
# Population                        NaN           NaN                 NaN
# Total Usage (kWh)            0.368604     -0.306230            0.344614
# Urban Usage (kWh)            0.331587     -0.284414            0.310905
# Rural Usage (kWh)            0.425498     -0.338992            0.392087
# Adjusted Total Usage (kWh)  -0.211088     -0.422122            0.277142
#
#                             Precipitation (mm)  Population  Total Usage (kWh)  \
# Temp (°C)                            -0.024681         NaN           0.368604
# Humidity (%)                          0.353851         NaN          -0.306230
# ...

# %%
print(correlation_df2)
# Out:
#                             Temp (°C)  Humidity (%)  Solar Energy (kWh)  \
# Temp (°C)                    1.000000     -0.225583            0.392008
# Humidity (%)                -0.225583      1.000000           -0.841592
# Solar Energy (kWh)           0.392008     -0.841592            1.000000
# Precipitation (mm)          -0.033250      0.215755           -0.215280
# Population                        NaN           NaN                 NaN
# Total Usage (kWh)            0.608473     -0.405270            0.536507
# Urban Usage (kWh)            0.593985     -0.396374            0.518406
# Rural Usage (kWh)            0.598512     -0.402241            0.532636
# Urban Household (kWh)        0.649246     -0.445892            0.580985
# Urban Industrial (kWh)       0.541332     -0.443310            0.533959
# Urban Commercial (kWh)       0.672216     -0.498677            0.626732
# Urban Others (kWh)           0.593994     -0.396378            0.518411
# ...

# %%
numerical_columns_df1 = df1.select_dtypes(include=['number']).columns
numerical_columns_df2 = df2.select_dtypes(include=['number']).columns

df1_distribution = df1[numerical_columns_df1].hist(figsize=(12, 10), bins=30)
df2_distribution = df2[numerical_columns_df2].hist(figsize=(12, 10), bins=30)
